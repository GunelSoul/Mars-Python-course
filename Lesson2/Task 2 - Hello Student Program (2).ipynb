# %% [markdown]
# ### [EN]
#
# **Hello Student Program**
# **Welcome, in this task you will practice variables and print function in python.**
#
# **Instruction:
# You have to write program which greet new student and tell us how many students there are in the group**
#
# Possible output: "Hi! Welcome to class Javid, there are 10 students in Python group"
#
# **Create 3 variables called 'name','greeting','number_of_students'**

# %% [markdown]
# ### [AZ]
#
# **Hello Student proqramı**
# **Salamlar, bu tapşırıqda sən dəyişənləri və print funksiyasını praktika edəcəksən**
#
# **Təlimat: Siz yeni tələbəni qarşılayan proqram yazmalı və qrupda neçə tələbənin olduğunu bildirməlisiniz**
#
# Mümkün output: "Salam! Cavid sinifə xoş gəlmisiniz, Python qrupunda 10 tələbə var"
#
# **"name", "greeting", "number_of_students" adlı 3 dəyişən yaradın**

# %%
# Write your code here

# %% [markdown]
# **Task2**:
#
# [ENG]
#
# Write program which tell how old will be student next year, using just 1 variable "age" which take in age of student now.
#
# [AZ]
#
# İndi tələbənin yaşını nəzərə alan cəmi 1 dəyişən "age" dan istifadə edərək gələn il neçə yaşında tələbə olacağını bildirən proqram yazın.

# %%
age = 10

# %% [markdown]
# **Output:** Hi! Next year you will be 11.

# %%
# Write your code here
