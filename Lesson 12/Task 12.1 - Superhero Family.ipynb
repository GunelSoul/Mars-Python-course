# %% [markdown]
# ### [EN]
#
# Superhero Family
#
# Instructions
#
# For this assignment, you will create your own superhero family using the concept of inheritance in Python. You will create a base class called Superhero which will have common attributes and methods shared by all superheroes. Then, you will create a few child classes that inherit from the 'Superhero' class, representing different types of superheroes.
#
# Your 'Superhero' class should have the following attributes:
#
# *   name: the name of the superhero (string)
# *   age: the age of the superhero (integer)
# *   power: the main power of the superhero (string)
#
# Your Superhero class should also have the following methods:
#
# greet(): a method that prints out a greeting message for the superhero, using their name and power
#
# Your child classes should represent different types of superheroes, such as:
#
# *   FlyingSuperhero: a superhero that can fly
# *   SuperStrengthSuperhero: a superhero that has super strength
# *   InvisibilitySuperhero: a superhero that can turn invisible
#
# Each child class should inherit the attributes and methods of the Superhero class, but can also have its own additional attributes and methods.
#
#
# For example, the FlyingSuperhero class could have an additional attribute called fly_speed and a method called fly() that allows the superhero to fly at a certain speed. The SuperStrengthSuperhero class could have an additional attribute called lifting_capacity and a method called lift() that allows the superhero to lift heavy objects.
#
# Once you have created your superhero family, create instances of each superhero and call their methods to showcase their unique powers. Have fun and be creative! :)

# %% [markdown]
# ### [AZ]
#
# Super qəhrəman ailəsi
#
# Təlimatlar
#
# Bu tapşırıqda "Inheritance" işlədərək "Super qəhrəman" ailəsi yaradacayıq. Bütün super qəhrəmanların ortaq olan attributları və metodlarını özündə saxlayacaq bir ana sinif (base class) yaradaq. Sonra, bu ana sinifdən törəyən bir neçə sinif yaradaq və bu siniflər müxtəlif super qəhrəmanları təmsil edəcək.
#
# "Superhero" sinfinin aşağıdakı atributları olmalıdır:
#
# *   name -> super qəhrəmanın adı (string)
# *   age -> super qəhrəmanın yaşı (integer)
# *   power -> super qəhrəmanın əsas gücü (string)
#
# "Superhero" sinifinin həmçinin aşağıdakı metodları da olmalıdır.
#
# greet() -> super qəhrəmanın adını və özəl gücünü istifadə edərək istifadəçini salamlayan bir metod
#
# Ana sinifdən (base class) törəyən aşağıdakı siniflər olmalıdır:
#
# *   FlyingSuperhero -> uça bilən bir super qəhrəman
# *   SuperStrengthSuperhero -> super gücü olan bir super qəhrəman
# *   InvisibilitySuperhero -> görünməz ola bilən bir super qəhrəman
#
# Hər törəyən sinif ana sinfin atributlarını və metodlarına sahib olmalıdır. Bunlardan əlavə, hər bir törəyən sinfin öz atribut və metodları da ola bilər.
#
# FlyingSuperhero sinfinin əlavə olaraq fly_speed atributu və fly() metodu olacaq. Bu method bu super qəhrəmanın müəyyən sürətdə uçmağı üçün istifadə olunacaq.
#
# SuperStrengthSuperhero sinfinin əlavə olaraq lifting_capacity atributu və lift() metodu olacaq. Bu metod super qəhrəmana ağır obyektləri qaldırmaq özəlliyi verəcəkdir.
#
# Super qəhrəman ailəsini yaratdıqdan sonra hər super qəhrəmanın bir obyektini yarat və onların metodlarını çağıraraq özəl güclərini göstər. Əylən və yaradıcı ol :).

# %%
# Write your code here
# Kodu buraya yazın
