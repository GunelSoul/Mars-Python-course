# %% [markdown]
# You are a fruit seller and you want to sort your basket of fruits in ascending order based on their length. Your task is to write a Python program that sorts the list of fruits based on their length using a lambda expression.
#
# Here are the detailed specifications for the program:
#
# **Input**
# The program should take a single input from the user:
# fruits_list: A list of fruits as strings. Each fruit name is at most 20 characters long.
#
# **Output**
# The program should print a sorted list of fruits in ascending order based on their length.
#
#
# **Example**
# Enter fruits separated by comma: banana,apple,pear,kiwi
#
# Output:
# ['kiwi', 'pear', 'apple', 'banana']
#
#
# You should implement the program that satisfies the above specifications. Use lambda expressions to accomplish the task.
#
# Here's a starter code that you can use:

# %%
fruits_list = input("Enter fruits separated by comma: ").split(",")
# Write your code here to sort the list of fruits using a lambda expression
