# %% [markdown]
# ### [EN]
#
# Even-Steven
#
# You have been given a list of integers, and you want to extract only the even numbers from the list. Your task is to write a Python program that extracts the even numbers using list comprehension and prints them out.
#
# Here are the detailed specifications for the program:
#
# **Input** <br>
# The program should take a single input from the user:
#
# numbers_list: A list of integers. The length of the list should be at most 10.
#
# **Output** <br>
# The program should print a list of even numbers extracted from the input list.
#
# **Example** <br>
# Enter numbers separated by comma: 1,2,3,4,5,6
#
# **Output:** <br>
# [2, 4, 6]

# %% [markdown]
# ### [AZ]
#
# Even-Steven
#
# Bizim bir tam ədəd listimiz var və bu listdən sadəcə cüt olan ədədləri çıxarmalıyıq. Bu tapşırıqda məqsədimiz "list comprehension" istifadə edərək cüt ədədləri listdən çıxarıb konsola yazdırmaqdır.
#
# **Daxil edilən**
#
# Proqram istifadəçidən bir neçə tam ədəd alıb, onları numbers_list listində saxlamalıdır.
#
# **Nəticə**
#
# Proqram daxil edilən listdəki bütün cüt ədədləri konsola yazmalıdır.
#
# **Nümunə**
# Vergüllə ayrılan sayları daxil edin: 1,2,3,4,5,6
#
# **Nəticə**
# [2,4,6]

# %%
numbers_list = [int(x) for x in input("Enter numbers separated by comma: ").split(",")]
# Write your code here
# Kodu buraya yazın
