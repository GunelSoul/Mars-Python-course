# %% [markdown]
# ### [EN]
#
# **Countdown program**
#
# **Instructions**
#
# **In this task, you will write a Python program that uses a loop to countdown from a given number to zero. The program should ask the user to input a number, and then use a for loop or while loop to print each number in the countdown**

# %% [markdown]
# ### [AZ]
#
# **Geri sayım proqramı**
#
# **Təlimatlar**
#
# **Bu tapşırıqda dövr istifadə edərək, verilən ədəddən 0-a qədər geri sayan bir proqram yazacaqsınız. Proqram ilk olaraq bu  almalıdır və döngü istifadə edərək, o ədəddən 0-a qədər bu ədədləri konsola yazdırmalıdır.**

# %%
# Write your code here
# Kodu buraya yazın
