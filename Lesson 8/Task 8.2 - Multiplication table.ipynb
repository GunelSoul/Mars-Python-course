# %% [markdown]
# ### [EN]
#
# Print the multiplication table of a given number using a for loop.
# Ask the user to input a number.
# Use a for loop to print the multiplication table of the given number from 1 to 10.
# Format the output so that each line of the multiplication table is aligned properly.
#
# Example Output:
#
# Enter a number: 5
#
# 5 x 1 = 5
#
# 5 x 2 = 10
#
# 5 x 3 = 15
#
# 5 x 4 = 20
#
# 5 x 5 = 25
#
# 5 x 6 = 30
#
# 5 x 7 = 35
#
# 5 x 8 = 40
#
# 5 x 9 = 45
#
# 5 x 10 = 50

# %% [markdown]
# ### [AZ]
#
# **High-Five**
#
# **Təlimatlar**
#
# "For loop" istifadə edərək verilmiş ədədin vurma cədvəlini çap edin.
# İstifadəçidən rəqəm daxil etməyi xahiş edin.
# 1-dən 10-a qədər verilmiş ədədin vurma cədvəlini çap etmək üçün "for loop"-dan istifadə edin.
# Çıxışı elə formatlayın ki, vurma cədvəlinin hər sətri düzgün düzülsün.
#
# Example Output:
#
# Enter a number: 5
#
# 5 x 1 = 5
#
# 5 x 2 = 10
#
# 5 x 3 = 15
#
# 5 x 4 = 20
#
# 5 x 5 = 25
#
# 5 x 6 = 30
#
# 5 x 7 = 35
#
# 5 x 8 = 40
#
# 5 x 9 = 45
#
# 5 x 10 = 50

# %%
# Write your code here
# Kodu buraya yazın
