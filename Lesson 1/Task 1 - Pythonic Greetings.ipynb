# %%
# Pythonic Greetings
# Welcome, in this task you are practice print function in python.

# Instruction:

# Using print function, print your name

# %%
#Python salamlama
#Salamlar, bu tapşırıqda sən pythonda print funksiyasını praktika edəcəksən

# Tılimat:

# print funksiyasını istifadə edərək, öz adınızı konsola yazdırın

# %%
# Write your code here
