# %% [markdown]
# ### [EN]
#
# **Weather Adviser**
#
# **Instructions**
#
# **You are a weather adviser and you want to help people decide what to wear for the day. Let's write a program to help us give advice on what to wear!
# First user should enter the temperature of weather.
# In the program, we have to write a new function called advice_clothes_type and we'll use an if statement to check the temperature and give advice on what to wear.**
#
# **If the temperature is less than 10 degrees Celsius, the function will print "It's very cold outside!
# Wear a warm jacket, hat, gloves and scarf." to let you know that you need to dress warmly.
# But if the temperature is between 10 and 20 degrees Celsius, the function will print
# "It's a bit chilly outside! Wear a sweater or light jacket." to let you know that
# you need to dress in layers. And if the temperature is greater than 20 degrees Celsius,
# the function will print "It's a warm day! Wear a t-shirt and shorts." to let you know that you can dress more lightly.**

# %% [markdown]
# ### [AZ]
#
# **Hava məsləhətçisi**
#
# **Təlimatlar**
#
# **Sən bir hava məsləhətçisisən və insanalara hər hansı bir gündə nə geyinəcəklərinə qərar verməyə kömək edirsən. Bunu proqram olaraq yazmağa nə deyirsen ? Ilk olaraq, istifadəçi hava temperaturunu daxil etməlidir. Bu proqramda, biz if kodlarını işlədərək bu temperaturu analiz edəcəyik və istifadəçilərə geyimləri ilə bağlı məsləhət verəcəyik.**
#
# **Əgər temperatur 10 dərəcə Selsidən azdırsa, advice_clothes_type funksiyası konsola "It's very cold outside!
# Wear a warm jacket, hat, gloves and scarf." mesajını çıxartmalıdır. Əgər ki, temperatur 10 və 20 dərəcə arasındadırsa, bu funksiya "It's a bit chilly outside! Wear a sweater or light jacket." mesajını konsola yazmalıdır. Son olaraq, əgər ki temperatur 20 dərəcədən çoxdursa, funksiya "It's a warm day! Wear a t-shirt and shorts." mesajını konsola yazmalıdır.**

# %%
temperature = int(input("What is the temperature of weather? "))

# Write your code here
