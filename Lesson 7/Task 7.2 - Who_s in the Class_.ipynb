# %% [markdown]
# ### [EN]
#
# **Who's in the Class?**
#
# **Instructions**
#
# **In this task, you will write a Python program that uses a if/esle and tuples to print out the names of students in a tuple, allowing you to take attendance and see who's present in the class.**

# %% [markdown]
# ### [AZ]
#
# **Kimlər dərsə gəlib ?**
#
# **Təlimatlar**
#
# **Bu tapşırıqda, if/else v tuple istifadə edərək tuple-da şagirdlərin adını konsola yazacaqsınız və kimlərin sinifd olduqunu yoxlaya biləcəksiniz.**

# %%
# initialize a tuple with the names of the students in the class
names = 

# prompt the user to enter a name to check, use input

# check if the name is in the class

if

else
