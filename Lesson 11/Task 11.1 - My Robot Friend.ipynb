# %% [markdown]
# ### [EN]
#
# **Instructions**
#
# **Hi there! Today, you're going to learn about Object-Oriented Programming (OOP) by creating your very own robot friend.**
#
# **Let's write a program to create a robot object that has some basic attributes and functions.**
#
# **First, we define a class called Robot. Inside the class, we define two attributes: name and color. Both of these attributes will be of string type and will represent name and color of the robot respectively.**
#
# **Next, we define two functions inside the Robot class. The first function is called introduce_self, and it will print a message introducing the robot by name and color. The second function is called change_color, and it will allow you to change the color of the robot.**
#
# **Now it's time to create your very own robot friend! Create an instance of the Robot class and give it a name and color. Use the introduce_self function to introduce your robot to yourself and others. Then, use the change_color function to change the color of your robot.**
#
# **Congratulations! You've just learned about Object-Oriented Programming and created your very own robot friend.**

# %% [markdown]
# ### [AZ]
#
# **Təlimatlar**
#
# **Hərkəsə salam. Bu gün, öz robot dostumuzu yaradaraq Obyekt Yönümlü Proqramlaşdırma (OOP) öyrənəcəyik.**
#
# **Bu proqramı biz sadə atributları və funksiyaları olan bir robot yaratmaq üçün istifadə edəcəyik.**
#
# **İlk olaraq, Robot adında bir sinif yaradırıq. Bu sinifdə iki atribut təyin edəcəyik: "name" və "color". Bu atributların hər ikisi "string" tipində bir dəyişən olacaq. "name" robotun adını, "color" isə robotun rəngini təmsil edəcək.**
#
# **Daha sonra Robot sinfinin içində "introduce_self" və "change_color" adında iki funksiya yaradırıq. "introduce_self" funksiyası robotun adını və rəngini ekrana yazaraq, onu təqdim edəcək. "change_color" funksiyasını istifadə edərək robotun rəngini dəyişə biləcəyik.**
#
# **Yuxarıdakıları hazırladığımıza görə artıq robot dostumuzu yaratmağın vaxtıdır! Robot sinfinin bir obyektini yarat və onun adını və rəngini təyin et. Robotu özünə və başqalarına tanıtmaq üçün onun "introduce_yourself" funksiyasını istifadə et. Daha sonra, "change_color" funksiyasını işlədərək robotun rəngini dəyiş.**
#
# **Təbriklər! Sən artıq Obyekt Yönümlü Proqramlaşdırmanı öyrəndin və özünün robot dostunu yaratdın!**

# %%
# Write your code here
# Kodu bura yazın
