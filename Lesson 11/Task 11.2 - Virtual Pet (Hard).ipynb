# %% [markdown]
# ### [EN]
#
# **Instructions**
#
# **Welcome to Virtual Pet - a program where you can create your very own virtual pet and take care of it!**
#
# **We will start by defining a class called Pet. Inside the class, we'll define three attributes: name, hunger and happiness. The name will be a string that represents the name of the pet, hunger will be an integer that represents the pet's hunger level (with 0 being not hungry and 10 being very hungry), and happiness will be an integer that represents the pet's happiness level (with 0 being very unhappy and 10 being very happy).**
#
# **Next, we'll define four functions inside the Pet class:**
#
# **The first function is called feed, and it will decrease the pet's hunger level by 1.**
#
# **The second function is called play, and it will increase the pet's happiness level by 1.**
#
# **The third function is called talk, and the pet will greet everyone and tell their name.**
#
# **The fourth function is called check_status, and it will print out the pet's current hunger and happiness levels.**
#
# **Now it's time to create your very own virtual pet! Create an instance of the Pet class and give it a name, hunger and happiness level. Use the talk function to make your pet greet everyone and tell their name, and the check_status function to see how your pet is feeling. Then, use the feed and play functions to take care of your pet by reducing its hunger level and increasing its happiness level.**

# %% [markdown]
# ### [AZ]
#
# **Təlimatlar**
#
# **Virtual ev heyvanını yarada bildiyin Virtual Pet proqramına xoş gəldin!**
#
# **İlk olaraq Pet adında bir sinif yaradacayıq və bu sinfin "name", "hunger" və "happiness" adında üç atributu olacaq. "name" "string" tipində və ev heyvanının adını təmsil edən bir dəyişən olacaq. "hunger" "integer" tipində və ev
# heyvanının aclığını göstərən bir dəyişən olacaq (0 - çox ac, 10 - tox vəziyyət). "happiness" "integer" tipində və ev heyvanının xoşbəxtlik səviyyəsini göstərən
# bir dəyişən olacaq (0 - üzgün, 10 - Ən xoşbəxt vəziyyət).**
#
# **İndi, Pet sinfinin içində 4 funksiya yaradaq.**
#
# **Birinci funksiyanın adı "feed" olacaq və o ev heyvanının aclıq səviyyəsini 1 vahid azaldacaq.**
#
# **Ikinci funksiyanın adı "play" olacaq və o ev heyvanının xoşbəxtlik səviyyəsini 1 vahid qaldıracaq.**
#
# **Üçüncü funksiyanın adı "talk" olacaq və ev heyvanı hamını salamlayacaq və öz adını deyəcək.**
#
# **Dördüncü funksiyanın adı "check_status" olacaq və o ev heyvanının hazırki aclıq və xoşbəxtlik səviyyəsini ekrana yazdıracaq.**
#
# **İndi isə öz ev heyvanını yaratmağın vaxtıdır! Pet sinfinin bir obyektini yarat və ona adını, aclıq və xoşbəxtlik səviyyələrini bildir. "talk" funksiyasını işlətdiyimiz zaman, ev heyvanımız hər kəsi salamlayacaq və öz adını hamıya deyəcək. "check_status" funksiyası isə sənin ev heyvanının aclıq və xoşbəxtliyini bildirərək onun necə hiss etdiyini sənə bildirəcək. Daha sonra, "feed" və "play" funksiyalarıyla ev heyvanının aclığını azaldaraq və xoşbəxtlik səviyyəsini yüksəldərək, onun qayğısına qal.**

# %%
# Write your code here
# Kodu bura yazın
