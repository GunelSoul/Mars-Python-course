# %% [markdown]
# ### [EN]
#
# **Instructions**
#
# **Let's help the local candy store by creating a program that will find all the candies that they have more than one of.**
#
# **To do this, we need to use something called a "list". A list is like a container that can hold lots of things, like candies!**
#
# **For example, let's say we have a list of candies like this:**
#
# candies = ["lollipop", "chocolate", "gummy bear", "lollipop", "sour patch", "chocolate"]
#
# **We can see that there are two "lollipop"s and two "chocolate"s in the list. Our task is to create a new list that only has the candies that appear more than once.**
#
# **Here's the steps to complete the task:**
#
# **1. Start by creating an empty list called "duplicates".**
#
# **2. Go through each candy in the original "candies" list one by one.**
#
# **3. Check if the candy is already in the "duplicates" list. If it is, skip it. If it's not, check if it appears more than once in the "candies" list.**
#
# **4. If the candy appears more than once, add it to the "duplicates" list.**
#
# **Here's an example of what the output should look like:**
#
# **Original list of candies:** ["lollipop", "chocolate", "gummy bear", "lollipop", "sour patch", "chocolate"]
#
# **List of candies with duplicates:** ["lollipop", "chocolate"]

# %% [markdown]
# ### [AZ]
#
# **Təlimatlar**
#
# **Sayı birdən çox olan şirniyyatları tapan bir proqram yazaraq yerli şirniyyat mağazasına kömək edək.**
#
# **Bunun üçün, "list" istifadə edəcəyik. "list" içində şirniyyatlar kimi çoxlu şeylər tutan bir qutu kimidir.**
#
# **Məsələn, bizim belə bir listimiz var:** candies = ["lollipop", "chocolate", "gummy bear", "lollipop", "sour patch", "chocolate"]
#
# **Bu listdə iki "lollipop" və iki "chocolate" olduğunu görə bilərik. Bizim tapşırığımız, iki və ya daha artıq sayda olan şirniyyatların olduğu yeni bir list yaratmaqdır.**
#
# **Bunun üçün aşağıdakı addımları izləyəcəyik:**
#
# **1. "duplicates" adında boş bir list yaradın**
#
# **2. "candies" listinin üstündə bir dəfə dövr edin**
#
# **3. Üstündən keçdikcə, hər şirniyyatın "duplicates" listində olub-olmadığını yoxlayın. Əgər ki, şirniyyatı əvvəldən tapmışıqsa, onu təkrardan "duplicates" listinə əlavə etməyə ehtiyac yoxdur. Əgər ki, şirniyyatı əvvəldən tapmamışıqsa, onun "candies" listində birdən çox olub-olmadığını yoxlayın.**
#
# **4. Əgər ki, şirniyyat iki və ya daha çoxdursa, onu "duplicates" listinə əlavə edin.**
#
# **Nümunə nəticə:**
#
# **Original şirniyyat listi:** ["lollipop", "chocolate", "gummy bear", "lollipop", "sour patch", "chocolate"]
#
# **İki və ya daha artıq şirniyyatların olduğu list:** ["lollipop", "chocolate"]

# %%
# Write your code here
# Kodu buraya yazın
