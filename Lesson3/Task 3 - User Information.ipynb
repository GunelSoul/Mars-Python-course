# %%
# Welcome, in this task you will practice input and + operator

# Instructions

# Get the user's name from the input and store it in a variable
# Get the user's age from the input and store it in a variable

# Then, create a variable called 'sentence' and assign
# 'My name is <name> and I am <age> years old' to it

# Lastly, print the sentence

# %%
# Salamlar, bu tapşırıqda sən istifadəçidən məlumat almağı və + operator işlətməyi öyrənəcəksən

# Təlimatlar

# İstifadəçinin adını konsoldan alın və bir dəyişənə mənimsədin
# İstifadəçinin yaşını konsoldan alın və bir dəyişənə mənimsədin

# Sonra, 'sentence' adında bir dəyişən yaradın və ona aşağıdakı mətni verilən formatda mənimsədin
# 'My name is <name> and I am <age> years old' to it

# Son olaraq, 'sentence' dəyişənini konsola yazdırın

# %%
# Wite your code here
